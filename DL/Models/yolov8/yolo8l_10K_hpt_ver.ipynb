# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 kB 52.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov8
# Out:
# /content/drive/.shortcut-targets-by-id/1N3hd8BTFKz67hdKAwuY0KaWwhIhiQhjO/SeSAC_Final_Project_새싹무침/model/yolov8

# %%
from ultralytics import YOLO

# YOLOv8 모델 로드
model = YOLO("yolov8l.pt")  # Pretrained 모델 경로 지정

# 학습 실행
model.train(
    task="detect",  # 탐지 작업
    data="/content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov8/yolov8l_pothole_10K.yaml",  # 데이터셋 설정 파일
    epochs=200,  # 에포크 수
    cfg="/content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov8/custom_args.yaml",  # 사용자 정의 하이퍼파라미터 설정 파일
    resume=False  # False면 처음부터 학습 시작, True면 이어서 학습
)
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...
