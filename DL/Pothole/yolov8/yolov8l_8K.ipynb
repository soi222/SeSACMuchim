# %%
from google.colab import drive
drive.mount('/content/Drive')
# Out:
# Mounted at /content/Drive

# %%
# %cd /content/Drive/MyDrive/SeSAC_Final_Project/model/yolov8
# Out:
# /content/Drive/.shortcut-targets-by-id/1N3hd8BTFKz67hdKAwuY0KaWwhIhiQhjO/SeSAC_Final_Project_새싹무침/model/yolov8

# %%
! pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 49.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8l.yaml")  # build a new model from scratch
model = YOLO("yolov8l.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/Drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov8/yolov8l_pothole_8K.yaml", epochs=150, imgsz=640, batch=64, device=0)
results = model.val()  # evaluate model performance on the validation set
results = model("/content/Drive/MyDrive/SeSAC_Final_Project_새싹무침/data/TEST_dataset/Pothole/3_pothole_total_619/Pothole_Image_Data/1.jpg")  # predict on an image
success = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.31 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
weights_path = '/content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov5/runs/train/exp13/weights/best.pt'

# %%
test_imate = '/content/drive/MyDrive/SeSAC_Final_Project_새싹무침/data/TEST_dataset/Pothole/3_pothole_total_619/Pothole_Image_Data/5.jpg'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.3/887.3 kB 46.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO("/content/drive/MyDrive/SeSAC_Final_Project/model/yolov8/runs/detect/train6/weights/best.pt")

# 이미지에서 검출 수행
results = model.predict(source="/content/drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0008.jpg", save=True, conf=0.25)

# 결과 저장 경로는 기본적으로 `runs/detect` 디렉토리입니다.
# Out:
# image 1/1 /content/drive/MyDrive/SeSAC_Final_Project_새싹무침/data/captured_frames/frame_0008.jpg: 384x640 1 pothole, 40.7ms
# Speed: 2.2ms preprocess, 40.7ms inference, 624.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2

# %%
from ultralytics import YOLO

# 모델 로드
model = YOLO("/content/Drive/MyDrive/SeSAC_Final_Project/model/yolov8/runs/detect/train6/weights/best.pt")

results = model.predict(
    source="/content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0008.jpg",
    save=True,
    save_dir="/content/Drive/MyDrive/SeSAC_Final_Project/results",
    conf=0.25
)
# Out:
# image 1/1 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0008.jpg: 384x640 1 pothole, 110.0ms
# Speed: 11.8ms preprocess, 110.0ms inference, 949.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
# from ultralytics import YOLO

# # 모델 로드
# model = YOLO("/content/Drive/MyDrive/SeSAC_Final_Project/model/yolov8/runs/detect/train6/weights/best.pt")

results = model.predict(
    source="/content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames",
    save=True,
    # save_dir="/content/Drive/MyDrive/SeSAC_Final_Project/results",
    conf=0.25
)
# Out:
# image 1/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0000.jpg: 384x640 1 pothole, 39.8ms
# image 2/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0001.jpg: 384x640 (no detections), 39.9ms
# image 3/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0002.jpg: 384x640 (no detections), 39.9ms
# image 4/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0003.jpg: 384x640 1 pothole, 39.9ms
# image 5/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0004.jpg: 384x640 (no detections), 39.9ms
# image 6/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0005.jpg: 384x640 (no detections), 40.8ms
# image 7/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0006.jpg: 384x640 (no detections), 39.9ms
# image 8/25 /content/Drive/MyDrive/SeSAC_Final_Project/data/captured_frames/frame_0007.jpg: 384x640 (no detections), 39.9ms
# ...

# %%
# 가장 최근에 저장된 경로 확인
print(results.save_dir)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-2863b2713313> in <cell line: 2>()
#       1 # 가장 최근에 저장된 경로 확인
# ----> 2 print(results.save_dir)
#
# AttributeError: 'list' object has no attribute 'save_dir'

# %%
# 디렉토리 확인
# !ls -l /content/drive/MyDrive/SeSAC_Final_Project_새싹무침
# Out:
# total 16
# drwx------  2 root root 4096 Nov 12 05:50  code
# drwx------ 16 root root 4096 Nov 12 05:44  data
# drwx------  4 root root 4096 Nov 14 07:10  model
# drwx------  2 root root 4096 Nov  1 04:15 'Study Files'

# %%
from PIL import Image

# 탐지 결과에서 첫 번째 이미지 가져오기
result_image = results[0].plot()

# 이미지 저장
Image.fromarray(result_image).save("/content/custom_predict_image.jpg")
