# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 19.6 MB/s eta 0:00:00
# ...

# %%
# !pip install models
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !python /content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov5/detect.py --weights /content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov8/runs/detect/train6/weights/best.pt --source /content/drive/MyDrive/SeSAC_Final_Project_새싹무침/data/captured_images/driving_pothole/images/frame_0007.jpg
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SeSAC_Final_Project_새싹무침/model/yolov5/detect.py", line 46, in <module>
#     from ultralytics.utils.plotting import Annotator, colors, save_one_box
# ModuleNotFoundError: No module named 'ultralytics'
